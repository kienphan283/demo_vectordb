# %% [markdown]
# <a href="https://colab.research.google.com/github/kienphan283/demo_vectordb_langchain/blob/master/llamaindex_vector_database.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install llama-index datasets "pinecone-client[grpc]" transformers

# %%
# %%capture
# %pip install llama-index-embeddings-instructor
# %pip install llama-index-embeddings-huggingface

# %%
# %pip install -U llama-index llama-index-embeddings-nomic
# Out:
# ...
#   Using cached llama_index_core-0.10.68.post1-py3-none-any.whl.metadata (2.5 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 2.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 4.8 MB/s eta 0:00:00
# Using cached llama_index_core-0.10.68.post1-py3-none-any.whl (1.6 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 6.7 MB/s eta 0:00:00
# ...
#   Created wheel for nomic: filename=nomic-3.1.1-py3-none-any.whl size=46185 sha256=71e026821305be862f8b4d3e3fbe0babcf4d852f5f763117995bdcaee4179f4b
#   Stored in directory: /root/.cache/pip/wheels/2c/2a/1d/a1adfcce3cf2df36a91ea14faf8c92ceeb8071ca7b595fdf59
# Successfully built nomic
# ...
#   Attempting uninstall: einops
#     Found existing installation: einops 0.8.0
#     Uninstalling einops-0.8.0:
#       Successfully uninstalled einops-0.8.0
# ...

# %%
data.shape
# Out:
# (18891, 3)

# %%
from llama_index.core import Document

docs = []

for i, row in data.iterrows():
    docs.append(Document(
        text = row['context'],
        doc_id = row['id'],
        extra_info = {
            'title': row['title']
        }
        ))
print(len(docs))
docs[0]
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /usr/local/lib/python3.10/dist-
# [nltk_data]     packages/llama_index/core/_static/nltk_cache...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# 18891
# ...

# %%
documents = docs[:100]
len(documents)
# Out:
# 100

# %%
from datasets import load_dataset
data = load_dataset('squad', split='train')
data = data.to_pandas()[['id', 'context', 'title']]
data.drop_duplicates(subset='context', keep='first', inplace=True)
data.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# Generating validation split:   0%|          | 0/10570 [00:00<?, ? examples/s]
#                           id  \
# 0   5733be284776f41900661182
# 5   5733bf84d058e614000b61be
# 10  5733bed24776f41900661188
# 15  5733a6424776f41900660f51
# 20  5733a70c4776f41900660f64
#
#                                               context  \
# 0   Architecturally, the school has a Catholic cha...
# 5   As at most other universities, Notre Dame's st...
# ...

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core import Settings
# Create an instance of the HuggingFaceEmbedding with the correct model name
embed_model = HuggingFaceEmbedding(
    model_name="BAAI/bge-small-en-v1.5"
)

# Assuming you have a correct way to set this in your settings or configuration
# This is a hypothetical example as the exact method to set this depends on the actual implementation of your settings management
Settings.set_embedding_model(embed_model)

# Now you can use embed_model for your tasks
# Example: Getting embeddings for a piece of text
embeddings = embed_model.get_embeddings("Your sample text here")
print(embeddings)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-2b0053f5acbe> in <cell line: 4>()
#       2 from llama_index.core import Settings
#       3 # Create an instance of the HuggingFaceEmbedding with the correct model name
# ----> 4 embed_model = HuggingFaceEmbedding(
#       5     model_name="BAAI/bge-small-en-v1.5"
#       6 )
#
# /usr/local/lib/python3.10/dist-packages/llama_index/embeddings/huggingface/base.py in __init__(self, model_name, tokenizer_name, pooling, max_length, query_instruction, text_instruction, normalize, model, tokenizer, embed_batch_size, cache_folder, trust_remote_code, device, callback_manager, parallel_process, target_devices, **model_kwargs)
#     132             tokenizer_name=tokenizer_name,
#     133             max_length=max_length,
# --> 134             pooling=pooling,
#     135             normalize=normalize,
# ...

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

# loads BAAI/bge-small-en-v1.5
embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-5a43a0e5144f> in <cell line: 4>()
#       2
#       3 # loads BAAI/bge-small-en-v1.5
# ----> 4 embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")
#
# /usr/local/lib/python3.10/dist-packages/llama_index/embeddings/huggingface/base.py in __init__(self, model_name, tokenizer_name, pooling, max_length, query_instruction, text_instruction, normalize, model, tokenizer, embed_batch_size, cache_folder, trust_remote_code, device, callback_manager, parallel_process, target_devices, **model_kwargs)
#     132             tokenizer_name=tokenizer_name,
#     133             max_length=max_length,
# --> 134             pooling=pooling,
#     135             normalize=normalize,
#     136             query_instruction=query_instruction,
#
# ...

# %%
embed_model = Settings.embed_model
embeddings = embed_model.get_text_embedding("Hello World!")
print(len(embeddings))
print(embeddings[:5])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-0b7841e515d6> in <cell line: 1>()
# ----> 1 embed_model = Settings.embed_model
#       2 embeddings = embed_model.get_text_embedding("Hello World!")
#       3 print(len(embeddings))
#       4 print(embeddings[:5])
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/settings.py in embed_model(self)
#      62         """Get the embedding model."""
#      63         if self._embed_model is None:
# ---> 64             self._embed_model = resolve_embed_model("default")
#      65
#      66         if self._callback_manager is not None:
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/embeddings/utils.py in resolve_embed_model(embed_model, callback_manager)
#      56             )  # pants: no-infer-dep
#      57
# ---> 58             embed_model = OpenAIEmbedding()
# ...

# %%
from llama_index.core import VectorStoreIndex

# Giả sử `documents` là list các Document đã được tạo từ DataFrame
index = VectorStoreIndex(documents)

# Lấy vector store từ index
vector_store = index.vector_store

# Thực hiện nhúng trên toàn bộ dataset
vector_store.add_documents(docs)
